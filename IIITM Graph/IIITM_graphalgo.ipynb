# %%
Node=list(set(("IIITM Gate","Nescafe Cafeteria","LT2","LT1","Admin Block","LT1 Cafeteria","Learning Resource Center","Convention Center","MDP","Gangotri Hostel","Health Center","IVH","OAT Cafeteria","Open Air Theater","Sports Complex","Shivalik Hostel","Aravalli","Nilgiri","Butterfly Garden")))
print(Node)
# Out:
# ['MDP', 'Shivalik Hostel', 'Nescafe Cafeteria', 'Aravalli', 'Convention Center', 'IIITM Gate', 'OAT Cafeteria', 'Butterfly Garden', 'Gangotri Hostel', 'Open Air Theater', 'LT2', 'Admin Block', 'Nilgiri', 'LT1 Cafeteria', 'Sports Complex', 'LT1', 'Learning Resource Center', 'Health Center', 'IVH']

# %%
Graph={
    "IIITM Gate":["Admin Block","MDP","Nescafe"],
    "Admin Block":["LT1","Convention Center","LRC","IIITM Gate"],
    "MDP":["IIITM Gate","Gangotri Hostel"],
    "Nescafe":["IIITM Gate","LT2","Nilgiri","Butterfly Garden"],
    "LT1":["LT2","Admin Block","LT1 Cafeteria"],
    "Convention Center":["LRC","Admin Block"],
    "LRC":["Convention Center","Admin Block","LT1 Cafeteria"],
    "Gangotri Hostel": ["MDP", "Health Center"],
    "LT2":["LT1","Nescafe"],
    "Nilgiri":["Aravalli","Butterfly Garden","Nescafe","LT1 Cafeteria"],
    "Butterfly Garden":["Nilgiri","Nescafe"],
    "LT1 Cafeteria":["LT1","LRC","Shivalik","Nilgiri","Aravalli"],
    "Health Center":["IVH","OAT","Gangotri Hostel"],
    "Shivalik":["Aravalli","OAT","LT1 Cafeteria"],
    "Aravalli":["Nilgiri","Shivalik","LT1 Cafeteria"],
    "OAT":["OAT Cafeteria","Sports Complex","Health Center","Shivalik"],
    "OAT Cafeteria":["OAT"],
    "Sports Complex":["OAT"],
    "IVH":["Health Center"],   
}

# %%
Weighted_Graph = {
    "IIITM Gate": [("Admin Block",200), ("MDP",150), ("Nescafe",500)],
    "Admin Block": [("LT1",50), ("Convention Center",100), ("LRC",150), ("IIITM Gate",200)],
    "MDP": [("IIITM Gate",150), ("Gangotri Hostel",250)],
    "Nescafe": [("IIITM Gate",500), ("LT2",30), ("Nilgiri",650), ("Butterfly Garden",600)],
    "LT1": [("LT2",100), ("Admin Block",50), ("LT1 Cafeteria",30)],
    "Convention Center": [("LRC",60), ("Admin Block",100)],
    "LRC": [("Convention Center",60), ("Admin Block",150), ("LT1 Cafeteria",30)],
    "Gangotri Hostel": [("MDP",250), ("Health Center",200)],
    "LT2": [("LT1",100), ("Nescafe",30)],
    "Nilgiri": [("Aravalli",20), ("Butterfly Garden",500), ("Nescafe",650), ("LT1 Cafeteria",300)],
    "Butterfly Garden": [("Nilgiri",500), ("Nescafe",600)],
    "LT1 Cafeteria": [("LT1",30), ("LRC",30), ("Shivalik",200), ("Nilgiri",300), ("Aravalli",220)],
    "Health Center": [("IVH",10), ("OAT",150), ("Gangotri Hostel",200)],
    "Shivalik": [("Aravalli",20), ("OAT",600), ("LT1 Cafeteria",200)],
    "Aravalli": [("Nilgiri",20), ("Shivalik",20), ("LT1 Cafeteria",220)],
    "OAT": [("OAT Cafeteria",20), ("Sports Complex",30), ("Health Center",150), ("Shivalik",600)],
    "OAT Cafeteria": [("OAT",20)],
    "Sports Complex": [("OAT",30)],
    "IVH": [("Health Center",10)],
}

# %%
# updating graph for navigation aware weighted graph
navigation_weighted_graph={
    "IIITM Gate":[
        ("Admin Block",{
            "distance":200,
            "direction":"straight",
            "landmarks": ["Main Gate", "Security Point", "Atal Bihari Vajpayee Statue"],
            "instruction":"Go straight from IIITM Gate towards Admin Block",
            "Special attraction":["Greenery walking path","Rest Point"]
        }),
        ("MDP",{
            "distance":150,
            "direction":"left",
            "landmakrs":["Main Gate","Security Point","Atal Bihari Vajpayee Statue"],
            "instruction": "Take left from Atal Bihari Vajpayee Statue and go straight towards MDP",
            "special attraction":["Large Cornifers","Dense fruit trees"]
        }),
        ("Nescafe",{
            "distance":500,
            "direction":"right",
            "landmakrs": ["Main Gate", "Security Point", "Atal Bihari Vajpayee Statue","Football Ground"],
            "instruction": "Take right from Atal Bihari Vajpayee Statue and go straight towards Nescafe",
            "special attraction":["Chilling enviornment","Multi-Purpose football ground","Jogging pathway"]
        })
    ],

    "Admin Block":[
        ("LT1",{
            "distance":50,
            "direction":"right",
            

        })
    ]
}
